# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import statistics

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/BIKE DETAILS.csv')

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
import os
import pandas as pd

file_path = "/content/BIKE DETAILS.csv"

# Check if the file exists
if not os.path.isfile("/content/BIKE DETAILS.csv"):
    print(f"Error: File '/content/BIKE DETAILS.csv' does not exist. Please check the path.")
else:
    try:
        # Load the file
        df = pd.read_csv("/content/BIKE DETAILS.csv")
        print("File loaded successfully!")

        # Verify the DataFrame
        if df is not None:
            print("DataFrame successfully loaded:")
            print(df.head())  # Preview the first few rows
        else:
            print("Error: DataFrame is None after loading.")
    except FileNotFoundError:
        print("Error: File not found. Please check the file path.")
    except pd.errors.EmptyDataError:
        print("Error: File is empty or contains no data.")
    except pd.errors.ParserError:
        print("Error: File is corrupted or not a valid CSV.")
# Out:
# File loaded successfully!
# DataFrame successfully loaded:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
df1=df.copy()

# %%
df1 #DATASET 1
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
'''Q1 What is the range of selling prices in the dataset'''

rnge=df1['selling_price'].max()-df1['selling_price'].min()

# %%
rnge
# Out:
# 755000

# %%
'''What is the median selling price for bikes in the dataset'''

med=df1['selling_price'].median()
med
# Out:
# 45000.0

# %%
'''What is the most common seller type'''

cmn=df1['seller_type'].mode()

# %%
cmn
# Out:
# 0    Individual
# Name: seller_type, dtype: object

# %%
'''How many bikes have driven more than 50,000 kilometers'''

bk=df1[df1['km_driven']>50000]
bk
# Out:
#                                name  selling_price  year seller_type  \
# 5                  Honda CB Twister          18000  2010  Individual
# 15    Suzuki Access 125 [2007-2016]          25000  2012  Individual
# 20             Hero Passion Pro 110          15000  2008  Individual
# 31          Yamaha FZ S [2012-2016]          38000  2013  Individual
# 43                Hero Passion XPro          28000  2012  Individual
# ...                             ...            ...   ...         ...
# 1049            Hero Super Splendor          20000  2007  Individual
# 1050               Bajaj Pulsar 150          20000  2010  Individual
# 1056                      Activa 3g          17000  2010  Individual
# 1059                 Honda CB Shine          12000  2009  Individual
# 1060               Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# 5     1st owner      60000            53857.0
# ...

# %%
k=len(bk)
k
# Out:
# 170

# %%
'''What is the average km_driven value for each ownership type'''

avg_km=df1.groupby('owner')['km_driven'].mean()

# %%
avg_km
# Out:
# owner
# 1st owner     32816.583333
# 2nd owner     39288.991870
# 3rd owner     33292.181818
# 4th owner    311500.000000
# Name: km_driven, dtype: float64

# %%
'''What proportion of bikes are from the year 2015 or older'''

prop=df1[df1['year']>2015]

# %%
prop
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 6                    Honda CB Hornet 160R          78500  2018  Individual
# 9                      Bajaj Discover 125          50000  2016  Individual
# ...                                   ...            ...   ...         ...
# 1034                     Honda CB Unicorn          38000  2017  Individual
# 1037                     Honda Activa 125          35000  2018  Individual
# 1038                          TVS Jupyter          35000  2016  Individual
# 1041                   Hero Splender Plus          30000  2018  Individual
# 1055                        Bajaj  ct 100          18000  2017  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
s=len(prop)

# %%
s
# Out:
# 460

# %%
'''What is the trend of missing values across the dataset'''

sns.heatmap(df1.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Value Heatmap')
plt.show()

# %%
'''What is the highest ex_showroom_price recorded, and for which bike'''

high_price=df1['ex_showroom_price'].max()

# %%
high_price
# Out:
# 1278000.0

# %%
high_price1=df1[df1['ex_showroom_price']==high_price]

# %%
high_price1
# Out:
#                            name  selling_price  year seller_type      owner  \
# 134  Harley-Davidson Street Bob         750000  2013  Individual  2nd owner
#
#      km_driven  ex_showroom_price
# 134      12000          1278000.0

# %%
'''What is the total number of bikes listed by each seller type'''

c=df1.groupby('seller_type')['name'].count()

# %%
c
# Out:
# seller_type
# Dealer           6
# Individual    1055
# Name: name, dtype: int64

# %%
'''What is the relationship between selling_price and km_driven for first-owner bikes'''

d=df1.groupby('owner')[['selling_price','km_driven']].count()
d
# Out:
#            selling_price  km_driven
# owner
# 1st owner            924        924
# 2nd owner            123        123
# 3rd owner             11         11
# 4th owner              3          3

# %%
'''Both are equal for first owner bikes'''
# Out:
# 'Both are equal for first owner bikes'

# %%
first_owner_bikes = df1[df1['owner'] == 'First Owner']
first_owner_bikes
# Out:
# Empty DataFrame
# Columns: [name, selling_price, year, seller_type, owner, km_driven, ex_showroom_price]
# Index: []

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
sns.barplot(x='km_driven', y='selling_price', data=first_owner_bikes)
plt.title('Relationship between Selling Price and Km Driven for First-Owner Bikes')
plt.xlabel('Km Driven')
plt.ylabel('Selling Price')
plt.show()

# %%
'''Identify and remove outliers in the km_driven column using the IQR method'''

Q1=df['km_driven'].quantile(0.25)
Q3=df['km_driven'].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 29500.0

# %%
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

upper_bound
# Out:
# 87250.0

# %%
lower_bound
# Out:
# -30750.0

# %%
outlier=df1[(df1['km_driven']<lower_bound) & (df1['km_driven']>upper_bound)]

# %%
print(outlier)
# Out:
# Empty DataFrame
# Columns: [name, selling_price, year, seller_type, owner, km_driven, ex_showroom_price]
# Index: []

# %%
'''No outlier is there'''
# Out:
# 'No outlier is there'

# %%
'''Perform a bivariate analysis to visualize the relationship between year and selling_price'''

plt.figure(figsize=(10, 6))
sns.barplot(x='year', y='selling_price', data=df1,color='r')
plt.title('Relationship between Year and Selling Price')
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.show()

# %%
'''What is the average depreciation in selling price based on the bike's age (current year - manufacturing
year)'''

df1['bike_age'] = 2025 - df1['year']
average_selling_price_by_age = df1.groupby('bike_age')['selling_price'].mean()
df1['depreciation'] = df1['ex_showroom_price'] - df1['selling_price']
average_depreciation_by_age = df1.groupby('bike_age')['depreciation'].mean()
print(average_depreciation_by_age)
# Out:
# bike_age
# 5    -34260.000000
# 6      2954.562500
# 7     13023.194805
# 8     22306.082353
# 9     28328.190476
# 10    28013.275000
# 11    34505.606061
# 12    43086.886792
# 13    37317.648649
# 14    47102.666667
# 15    45658.928571
# 16    38227.785714
# 17    54732.428571
# 18    42399.000000
# 19    39664.500000
# 20    44852.000000
# 21    36852.000000
# 22             NaN
# 23             NaN
# 24    34852.000000
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 30             NaN
# 32             NaN
# 34             NaN
# 37             NaN
# Name: depreciation, dtype: float64

# %%
'''Which bike names are priced significantly above the average price for their manufacturing year'''
a = df1.groupby('year')['selling_price'].mean()
a
# Out:
# year
# 1988     20000.000000
# 1991      6000.000000
# 1993    130000.000000
# 1995    150000.000000
# 1997     17500.000000
# 1998     28333.333333
# 1999     15000.000000
# 2000     20833.333333
# 2001     40000.000000
# 2002     20666.666667
# 2003      8000.000000
# 2004     15100.000000
# 2005     16978.571429
# 2006     23380.000000
# 2007     24927.586207
# 2008     34289.285714
# 2009     22267.857143
# 2010     31793.333333
# 2011     35655.721311
# 2012     35748.400000
# 2013     51136.986301
# 2014     48668.131868
# 2015     56500.000000
# 2016     58469.018692
# 2017     78894.736842
# 2018     87660.374046
# 2019    119689.511628
# 2020    183333.333333
# Name: selling_price, dtype: float64

# %%
'''Develop a correlation matrix for numeric columns and visualize it using a heatmap.'''

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
#  7   bike_age           1061 non-null   int64
#  8   depreciation       626 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 74.7+ KB

# %%
int_cols = df1.select_dtypes(include=['int64', 'int32']).columns
int_df = df1[int_cols]
correlation_matrix = int_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Integer Columns')
plt.show()
